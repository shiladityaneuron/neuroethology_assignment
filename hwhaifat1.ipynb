# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
trainingdata=pd.read_csv('/Users/shila/Downloads/hwdata_haifa/train.csv')
trainingdata.keys()
# Out:
# Index(['Unnamed: 0', 'M_X_head', 'M_X_thorax', 'M_X_abdomen', 'M_X_wingL',
#        'M_X_wingR', 'M_X_forelegL4', 'M_X_forelegR4', 'M_X_midlegL4',
#        'M_X_midlegR4', 'M_X_hindlegL4', 'M_X_hindlegR4', 'M_X_eyeL',
#        'M_X_eyeR', 'M_Y_head', 'M_Y_thorax', 'M_Y_abdomen', 'M_Y_wingL',
#        'M_Y_wingR', 'M_Y_forelegL4', 'M_Y_forelegR4', 'M_Y_midlegL4',
#        'M_Y_midlegR4', 'M_Y_hindlegL4', 'M_Y_hindlegR4', 'M_Y_eyeL',
#        'M_Y_eyeR', 'F_X_head', 'F_X_thorax', 'F_X_abdomen', 'F_X_wingL',
#        'F_X_wingR', 'F_X_forelegL4', 'F_X_forelegR4', 'F_X_midlegL4',
#        'F_X_midlegR4', 'F_X_hindlegL4', 'F_X_hindlegR4', 'F_X_eyeL',
#        'F_X_eyeR', 'F_Y_head', 'F_Y_thorax', 'F_Y_abdomen', 'F_Y_wingL',
#        'F_Y_wingR', 'F_Y_forelegL4', 'F_Y_forelegR4', 'F_Y_midlegL4',
#        'F_Y_midlegR4', 'F_Y_hindlegL4', 'F_Y_hindlegR4', 'F_Y_eyeL',
#        'F_Y_eyeR', 'Label'],
#       dtype='object')

# %%
nan_rows = trainingdata[trainingdata.isna().any(axis=1)]
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, M_X_head, M_X_thorax, M_X_abdomen, M_X_wingL, M_X_wingR, M_X_forelegL4, M_X_forelegR4, M_X_midlegL4, M_X_midlegR4, M_X_hindlegL4, M_X_hindlegR4, M_X_eyeL, M_X_eyeR, M_Y_head, M_Y_thorax, M_Y_abdomen, M_Y_wingL, M_Y_wingR, M_Y_forelegL4, M_Y_forelegR4, M_Y_midlegL4, M_Y_midlegR4, M_Y_hindlegL4, M_Y_hindlegR4, M_Y_eyeL, M_Y_eyeR, F_X_head, F_X_thorax, F_X_abdomen, F_X_wingL, F_X_wingR, F_X_forelegL4, F_X_forelegR4, F_X_midlegL4, F_X_midlegR4, F_X_hindlegL4, F_X_hindlegR4, F_X_eyeL, F_X_eyeR, F_Y_head, F_Y_thorax, F_Y_abdomen, F_Y_wingL, F_Y_wingR, F_Y_forelegL4, F_Y_forelegR4, F_Y_midlegL4, F_Y_midlegR4, F_Y_hindlegL4, F_Y_hindlegR4, F_Y_eyeL, F_Y_eyeR, Label]
# Index: []
#
# [0 rows x 54 columns]

# %%
#Lets Visualize the data
plt.figure(1)
plt.scatter(trainingdata['M_X_head'],trainingdata['M_Y_head'],s=0.2)
plt.scatter(trainingdata['F_X_head'],trainingdata['F_Y_head'],s=0.2)

plt.figure(2)
#Plot frame 1 with body characterestics

plt.scatter()

# %%
empty_or_nan_rows = df[df.isna().any(axis=1) | (df.applymap(lambda x: isinstance(x, str) and x.strip() == '')).any(axis=1)]
